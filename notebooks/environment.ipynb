# %% [markdown]
# # Environment Overview

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append('../')

from pgtaa.environment import *
from pgtaa.core.utils import read_data

# %%
data = read_data(cfg.TRAIN_CSV, nb_assets=8, lin_return=True, return_array=False)

# %%
data
# Out:
#             iShares Russell 1000 Value ETF (IWD)  \
# 2005-01-10                              0.004013
# 2005-01-11                             -0.006302
# 2005-01-12                              0.002320
# 2005-01-13                             -0.004784
# 2005-01-14                              0.005892
# 2005-01-18                              0.010174
# 2005-01-19                             -0.008088
# 2005-01-20                             -0.005846
# 2005-01-21                             -0.004643
# 2005-01-24                              0.001244
# 2005-01-25                              0.000932
# 2005-01-26                              0.001862
# 2005-01-27                              0.000774
# 2005-01-28                             -0.001702
# 2005-01-31                              0.010694
# 2005-02-01                              0.008741
# 2005-02-02                              0.003953
# 2005-02-03                             -0.001666
# ...
